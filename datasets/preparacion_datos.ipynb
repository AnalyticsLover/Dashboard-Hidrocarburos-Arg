# %% [markdown]
# # **Proyecto: Producción de hidrocarburos en la Nación Argentina**
#
#
# ## Fases del proyecto
# ### 1. Preparación y limpieza de los datos
# ### 2. Feature engineering (creación de campos nuevos)
# ### 3. Analisis inicial
# ### 4. Creación de archivo final csv
# ### 5. Creación de visualizaciones y filtros
#
# ------------------------------------------------------------------------------------------------------------------------------------

# %% [markdown]
# ### Fase 1: Importando, limpiando y preparando los datos
# Transformaiones a realizar:
# * Encargarse de informacion incompleta y mal formateada
# * Corregir inconsistencias
# * Establecer tipos de datos correctos a los campos

# %%
import pandas as pd 
import numpy as np
import plotly.express as px

# %%
data = pd.read_csv('datos-de-fractura-de-pozos-de-hidrocarburos.csv')
#data_cuencas = pd.read_csv("cuencas-sedimentarias.csv")
data_petro = pd.read_csv("prod-petro-por-yacimiento.csv")
data_gas = pd.read_csv("prod-gas-por-yacimiento.csv")

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4062 entries, 0 to 4061
# Data columns (total 30 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   id_base_fractura_adjiv        4062 non-null   int64
#  1   idpozo                        4062 non-null   int64
#  2   sigla                         4062 non-null   object
#  3   cuenca                        4062 non-null   object
#  4   areapermisoconcesion          4062 non-null   object
#  5   yacimiento                    4062 non-null   object
#  6   formacion_productiva          4062 non-null   object
#  7   tipo_reservorio               4024 non-null   object
#  8   subtipo_reservorio            3150 non-null   object
#  9   longitud_rama_horizontal_m    4062 non-null   float64
#  10  cantidad_fracturas            4062 non-null   int64
#  11  tipo_terminacion              4062 non-null   object
#  12  arena_bombeada_nacional_tn    4062 non-null   float64
#  13  arena_bombeada_importada_tn   4062 non-null   float64
#  14  agua_inyectada_m3             4062 non-null   float64
#  15  co2_inyectado_m3              4062 non-null   float64
#  16  presion_maxima_psi            4062 non-null   float64
#  17  potencia_equipos_fractura_hp  4011 non-null   float64
#  18  fecha_inicio_fractura         4062 non-null   object
#  19  fecha_fin_fractura            4062 non-null   object
#  20  fecha_data                    4062 non-null   object
#  21  anio_if                       4062 non-null   int64
#  22  mes_if                        4062 non-null   int64
#  23  anio_ff                       4062 non-null   int64
#  24  mes_ff                        4062 non-null   int64
#  25  anio_carga                    4062 non-null   int64
#  26  mes_carga                     4062 non-null   int64
#  27  empresa_informante            4062 non-null   object
#  28  mes                           4062 non-null   int64
#  29  anio                          4062 non-null   int64
# dtypes: float64(7), int64(11), object(12)
# memory usage: 952.2+ KB

# %%
data["fecha_inicio_fractura"] = pd.to_datetime(data["fecha_inicio_fractura"], errors="coerce")
data["fecha_fin_fractura"] = pd.to_datetime(data["fecha_fin_fractura"], errors="coerce")
data = data.drop(columns=["anio", "mes", "empresa_informante", "mes_carga", "anio_carga", "fecha_data"])
data = data.rename(columns={"anio_if": "año_if", "anio_ff": "año_ff", "areapermisoconcesion": "area_permiso_concesion", "idpozo": "id_pozo"})

# %%
data[data["subtipo_reservorio"].isna()]
#print(data.duplicated().sum())
#data.drop_duplicates()
#data.dropna()
#data["cuenca"] = data["cuenca"].replace("AUSTRAL MARINA", "AUSTRAL")
# Out:
#       id_base_fractura_adjiv  id_pozo               sigla           cuenca  \
# 717                      893   136243    YPF.SC.ALLCN.x-2          AUSTRAL
# 789                     1114   160771     CGC.SCA.EPu.a-4          AUSTRAL
# 842                     1176     8788        SJ.Nq.Cc.x-1         NEUQUINA
# 843                     1177   136559   CHA.Nq.ET.ia-1195         NEUQUINA
# 844                     1178   136362   CHA.Nq.ET.ia-1280         NEUQUINA
# ...                      ...      ...                 ...              ...
# 3519                    4201   164457      CGC.SC.EH-5015  GOLFO SAN JORGE
# 3520                    4202   164457      CGC.SC.EH-5015  GOLFO SAN JORGE
# 3521                    4203   164457      CGC.SC.EH-5015  GOLFO SAN JORGE
# 3652                    4334   164943  VIS.Nq.BPO-2803(h)         NEUQUINA
# 3836                    4558    73832        Q.SC.ALP.a-2          AUSTRAL
#
#               area_permiso_concesion                   yacimiento  \
# 717        SANTA CRUZ I - FRACCION C  LAGUNA DE LOS CAPONES NORTE
# 789   CAMPO INDIO ESTE - EL CERRITO                       EL PUMA
# 842           EL TRAPIAL - CURAMCHED                    CURAMCHED
# 843                  EL TRAPIAL ESTE                   EL TRAPIAL
# 844                  EL TRAPIAL ESTE                   EL TRAPIAL
# ...                              ...                          ...
# 3519        EL HUEMUL - KOLUEL KAIKE                    EL HUEMUL
# 3520        EL HUEMUL - KOLUEL KAIKE                    EL HUEMUL
# 3521        EL HUEMUL - KOLUEL KAIKE                    EL HUEMUL
# 3652           BAJADA DEL PALO OESTE        BAJADA DEL PALO OESTE
# 3836                          LA PAZ                       LA PAZ
#
#      formacion_productiva  tipo_reservorio subtipo_reservorio  \
# 717            springhill              NaN                NaN
# 789                 ANITA     CONVENCIONAL                NaN
# 842                 agrio     CONVENCIONAL                NaN
# 843               huitrín     CONVENCIONAL                NaN
# 844                rayoso     CONVENCIONAL                NaN
# ...                   ...              ...                ...
# 3519         cañadon seco     CONVENCIONAL                NaN
# 3520         cañadon seco     CONVENCIONAL                NaN
# 3521         cañadon seco     CONVENCIONAL                NaN
# 3652          vaca muerta  NO DISCRIMINADO                NaN
# 3836           springhill              NaN                NaN
#
#       longitud_rama_horizontal_m  ...  agua_inyectada_m3 co2_inyectado_m3  \
# 717                          0.0  ...            176.790              0.0
# 789                          0.0  ...             57.406              0.0
# 842                          0.0  ...            109.000              0.0
# 843                          0.0  ...             87.000              0.0
# 844                          0.0  ...            105.000              0.0
# ...                          ...  ...                ...              ...
# 3519                         4.0  ...            105.000              0.0
# 3520                         4.0  ...             97.000              0.0
# 3521                         3.0  ...             97.000              0.0
# 3652                      3220.0  ...          96741.136              0.0
# 3836                        32.8  ...           1819.200              0.0
#
#       presion_maxima_psi  potencia_equipos_fractura_hp  fecha_inicio_fractura  \
# 717               3322.0                        1063.0             2019-04-29
# 789               2675.0                         707.0             2019-02-14
# 842               5780.0                        2433.0             2010-11-14
# 843               3050.0                        1038.0             2011-09-08
# 844               1550.0                         515.0             2011-08-04
# ...                  ...                           ...                    ...
# 3519              6425.0                        2097.0             2023-06-21
# 3520              5470.0                        1563.0             2023-06-22
# 3521              5340.0                        1580.0             2023-06-23
# 3652             12899.0                       27293.6             2024-01-15
# 3836              6652.0                        8788.0             2024-05-30
#
#       fecha_fin_fractura  año_if  mes_if año_ff mes_ff
# 717           2019-04-29    2019       4   2019      4
# 789           2019-02-14    2019       2   2019      2
# 842           2010-11-14    2010      11   2010     11
# 843           2011-09-08    2011       9   2011      9
# 844           2011-08-04    2011       8   2011      8
# ...                  ...     ...     ...    ...    ...
# 3519          2023-06-21    2023       6   2023      6
# 3520          2023-06-22    2023       6   2023      6
# 3521          2023-06-23    2023       6   2023      6
# 3652          2024-02-03    2024       1   2024      2
# 3836          2024-05-30    2024       5   2024      5
#
# [912 rows x 24 columns]

# %% [markdown]
# ### Inspeccionando, limpiando y transformando el resto de datos

# %%
prod_data = pd.concat([data_petro, data_gas], ignore_index=True)

# %%
prod_data.head()
# Out:
#   indice_tiempo  anio  mes idempresa                              empresa  \
# 0       2025-01  2025    1       PAL               PAN AMERICAN ENERGY SL
# 1       2025-01  2025    1       CAP  COMPAÑÍAS ASOCIADAS PETROLERAS S.A.
# 2       2025-01  2025    1       PAL               PAN AMERICAN ENERGY SL
# 3       2025-01  2025    1       PLU                      PLUSPETROL S.A.
# 4       2025-01  2025    1       PLU                      PLUSPETROL S.A.
#
#   idareapermisoconcesion                  areapermisoconcesion  \
# 0                   CGCH  CENTRO GOLFO SAN JORGE MARINA CHUBUT
# 1                   SIND                             SINDICATO
# 2                   CGCH  CENTRO GOLFO SAN JORGE MARINA CHUBUT
# 3                   PSOE                    PUESTO SILVA OESTE
# 4                   PSOE                    PUESTO SILVA OESTE
#
#   idareayacimiento      areayacimiento idcuenca  ... idprovincia  provincia  \
# 0             Y040    CGSJM-1 (Chubut)      GSJ  ...           U     Chubut
# 1             SIND           SINDICATO      GSJ  ...           U     Chubut
# 2             Y040    CGSJM-1 (Chubut)      GSJ  ...           U     Chubut
# 3              PSI  PUESTO SILVA OESTE      NEU  ...           R  Rio Negro
# 4              PSI  PUESTO SILVA OESTE      NEU  ...           R  Rio Negro
#
#   idubicacion  ubicacion idconcepto  \
# 0           2  Off Shore          1
# 1           1   On Shore          3
# 2           2  Off Shore          2
# 3           1   On Shore          1
# 4           1   On Shore          3
#
#                                     concepto cantidad  \
# 0                   Producción Primaria (m3)      0.0
# 1  Producción por Recuperación Asistida (m3)      0.0
# 2                 Producción Secundaria (m3)      0.0
# 3                   Producción Primaria (m3)      0.0
# 4  Producción por Recuperación Asistida (m3)      0.0
#
#                                     observaciones desc_mes  fecha_data
# 0  Cargado automaticamente como [Sin movimientos]    Enero  2025-01-31
# 1                                             NaN    Enero  2025-01-31
# 2  Cargado automaticamente como [Sin movimientos]    Enero  2025-01-31
# 3  Cargado automaticamente como [Sin movimientos]    Enero  2025-01-31
# 4  Cargado automaticamente como [Sin movimientos]    Enero  2025-01-31
#
# [5 rows x 21 columns]

# %%
prod_data = prod_data.rename(columns={"anio": "año", "idempresa": "id_empresa", "idareapermisoconcesion": "id_area_permiso_concesion",
                              "areapermisoconcesion": "area_permiso_concesion", "idareayacimiento": "id_area_yacimiento",
                              "areayacimiento": "area_yacimiento", "idcuenca": "id_cuenca", "idprovincia": "id_provincia",
                              "idubicacion": "id_ubicacion", "idconcepto": "id_concepto"})
prod_data["indice_tiempo"] = pd.to_datetime(prod_data["indice_tiempo"], errors="coerce")

# %%
prod_data = prod_data.drop(columns=["observaciones", "desc_mes", "fecha_data"])

# %%
prod_data = prod_data[prod_data["cantidad"] > 0]

# %%
prod_data["concepto"].unique()
# Out:
# array(['Producción Primaria (m3)', 'Producción de Agua (m3)',
#        'Inyección de Agua (m3)', 'Producción No Convencional (m3)',
#        'Densidad Media (Ton/m3)',
#        'Producción de Gasolina Estabilizada (m3)',
#        'Producción de Condensado (m3)', 'Producción Secundaria (m3)',
#        'Consumo en Yacimiento (m3)',
#        'Producción por Recuperación Asistida (m3)',
#        'Gas de Baja Presión (Mm3)', 'Gas de Media Presión (Mm3)',
#        'Gas de Alta Presión (Mm3)', 'Inyectado a Formación (Mm3)',
#        'Equivalente calórico del gas (Kcal/m3)',
#        'Gas No Convencional (Mm3)', 'Inyección para Almacenamiento (Mm3)',
#        'Extraído del almacenamiento (Mm3)'], dtype=object)

# %%
def normalizar_unidades(row):
    if 'Mm3' in row["concepto"]:
        return row["cantidad"] * 1e6
    return row["cantidad"]

# %%
clean_prod_data = prod_data.assign(
    cantidad_normalizada = lambda x: x.apply(normalizar_unidades, axis=1),
    tipo_producto= lambda x: np.select(
        [
            x["concepto"].str.contains("Gas"),
            x["concepto"].str.contains("Primaria|Secundaria|Gasolina|Recuperación|Producción No Convencional"),
            x["concepto"].str.contains("Producción de Agua")
        ],
        ["Gas", "Petróleo", "Agua"],
        default="Otro"
    )
).dropna()

# %%
print(clean_prod_data.groupby("tipo_producto")["cantidad_normalizada"].describe())
# Out:
#                   count          mean           std     min          25%  \
# tipo_producto
# Agua           104498.0  5.322575e+04  1.734048e+05  0.0010      347.340
# Gas            144424.0  6.214300e+09  2.654601e+10  0.0020  2530000.000
# Otro           221654.0  2.480146e+07  4.921789e+08  0.0100        0.900
# Petróleo       129111.0  4.449440e+03  1.480206e+04  0.0001      155.505
#
#                         50%           75%           max
# tipo_producto
# Agua           2.896980e+03  2.036073e+04  2.221603e+06
# Gas            1.845870e+08  1.943272e+09  6.597156e+11
# Otro           5.073070e+03  1.024162e+04  7.882821e+10
# Petróleo       7.210900e+02  3.267262e+03  3.682665e+05

# %%
#final_data.to_csv("Hidrocarburos Argentina Datos Limpios.csv", index=False)

# %%
px.histogram(
    clean_prod_data,
    x='indice_tiempo',
    color='tipo_producto',
    title='Distribución temporal por tipo de fluido'
).show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[16], line 6
#       1 px.histogram(
#       2     clean_prod_data,
#       3     x='indice_tiempo',
#       4     color='tipo_producto',
#       5     title='Distribución temporal por tipo de fluido'
# ----> 6 ).show()
#
# File c:\Users\Lucia\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\basedatatypes.py:3414, in BaseFigure.show(self, *args, **kwargs)
#    3381 """
#    3382 Show a figure using either the default renderer(s) or the renderer(s)
#    3383 specified by the renderer argument
#    (...)   3410 None
#    3411 """
#    3412 import plotly.io as pio
# -> 3414 return pio.show(self, *args, **kwargs)
#
# File c:\Users\Lucia\AppData\Local\Programs\Python\Python313\Lib\site-packages\plotly\io\_renderers.py:425, in show(fig, renderer, validate, **kwargs)
#     420     raise ValueError(
#     421         "Mime type rendering requires ipython but it is not installed"
#     422     )
#     424 if not nbformat or Version(nbformat.__version__) < Version("4.2.0"):
# --> 425     raise ValueError(
#     426         "Mime type rendering requires nbformat>=4.2.0 but it is not installed"
#     427     )
#     429 display_jupyter_version_warnings()
#     431 ipython_display.display(bundle, raw=True)
#
# ValueError: Mime type rendering requires nbformat>=4.2.0 but it is not installed

# %%
# !pip show nbformat jupyter
# Out:
# WARNING: Package(s) not found: jupyter, nbformat

# %%
clean_prod_data.to_parquet('data/processed/produccion_clean.parquet')
#data.to_parquet('data/processed/fracturas_clean.parquet')
